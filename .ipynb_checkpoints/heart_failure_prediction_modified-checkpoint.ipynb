# %% [markdown]
# # Welcome to My Notebook!
#
# Hello and welcome! Thank you for taking the time to explore this notebook. In this notebook, I will walk you through [briefly explain the content or goal of your notebook].
#
# If you find this notebook helpful or insightful, I would truly appreciate it if you could give an upvote! Your support helps others discover useful content and motivates me to create more.

# %% [markdown]
# ## Content

# %% [markdown]
# Hello and welcome! In this notebook, I will guide you through the process of analyzing and predicting heart disease using a dataset containing key features related to heart health. The goal of this notebook is to build a machine learning model that can predict the likelihood of heart disease based on various input features such as age, blood pressure, cholesterol levels, and more.
#
# Throughout this notebook, we will:
# - Explore and preprocess the dataset
# - Perform exploratory data analysis (EDA) to uncover patterns and insights
# - Train machine learning models for heart disease prediction
# - Evaluate and fine-tune the model to improve accuracy

# %%
# !pip install plotly

#imports
#data management
import pandas as pd
import numpy as np
#model selection
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
#visualization
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
#ML algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
#extra
import warnings
warnings.filterwarnings("ignore")
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: plotly in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (6.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from plotly) (1.25.2)
# Requirement already satisfied: packaging in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from plotly) (24.1)

# %%
#load data
db = pd.read_csv("heart2.csv")
#we will use copy of our data for visualization and analysis
db_copy = db.copy()

# %% [markdown]
# <a id =1></a>
# # Exploratory Analysis

# %%
#fist 5 samples
db.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
# 5              N      0.0       Up             0
# 6              N      0.0       Up             0
# 7              N      0.0       Up             0
# 8              Y      1.5     Flat             1
# 9              N      0.0       Up             0

# %%
#info
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# <font color = #8B0000>
# As it can be seen we have no null values
# </font>

# %%
#statistic informations
db.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# <font color = #8B0000>
# We will normalize the data to get more accurate score</br>
# Normalizing means fitting our data into 0 and 1 </br>
# We will talk more about it later</br>
# </font>

# %%
db['ChestPainType'].unique
# Out:
# <bound method Series.unique of 0      ATA
# 1      NAP
# 2      ATA
# 3      ASY
# 4      NAP
#       ...
# 913     TA
# 914    ASY
# 915    ASY
# 916    ATA
# 917    NAP
# Name: ChestPainType, Length: 918, dtype: object>

# %%
#value counts of categorical features
categoricalfeatures = ["ChestPainType","RestingECG","Sex","ExerciseAngina","ST_Slope"]
for i in categoricalfeatures:
    print(db[i].value_counts())
    print("***************************")
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64
# ***************************
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64
# ***************************
# Sex
# M    725
# F    193
# Name: count, dtype: int64
# ***************************
# ExerciseAngina
# N    547
# Y    371
# Name: count, dtype: int64
# ***************************
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64
# ***************************

# %% [markdown]
# ### İntroduction of all features

# %% [markdown]
# | Feature          | Description                                                                                   |
# |------------------|-----------------------------------------------------------------------------------------------|
# | **Age**          | Age of the patient [years]                                                                    |
# | **Sex**          | Sex of the patient [M: Male, F: Female]                                                       |
# | **ChestPainType**| Chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic] |
# | **RestingBP**    | Resting blood pressure [mm Hg]                                                                |
# | **Cholesterol**  | Serum cholesterol [mm/dl]                                                                     |
# | **FastingBS**    | Fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]                               |
# | **RestingECG**   | Resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality, LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria] |
# | **MaxHR**        | Maximum heart rate achieved [Numeric value between 60 and 202]                                |
# | **ExerciseAngina**| Exercise-induced angina [Y: Yes, N: No]                                                      |
# | **Oldpeak**      | Oldpeak = ST depression [Numeric value measured in depression]                                |
# | **ST_Slope**     | The slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]      |
# | **HeartDisease** | Output class [1: heart disease, 0: Normal]                                                   |

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### MaxHr - Age

# %%
sns.lineplot(db_copy , x = "Age" , y = "MaxHR")
plt.title("MaxHr - Age")
plt.show()

# %% [markdown]
# ###

# %% [markdown]
# <font color = red>Which means younger people have more MaxHR rate than older people</font>

# %% [markdown]
# ### RestingBP - Cholesterol

# %%
restingbp = [None if each == 0 else each for each in db_copy["RestingBP"]]
sns.lineplot(db_copy , x = restingbp , y = "Cholesterol")
plt.xlabel("Resting Blood Pressure")
plt.title("RestingBP - Cholesterol")
plt.show()

# %% [markdown]
# <font color = red>It seems restingbp has nothing to do with cholestorol</font>

# %% [markdown]
# ### RestingBP - Age

# %%
sns.lineplot(db_copy , x = restingbp , y = "Age")
plt.xlabel("Resting Blood Pressure")
plt.title("RestingBP - Age")
plt.show()

# %% [markdown]
# <font color = red>It seems that as age increases, resting blood pressure also increases.</font>

# %% [markdown]
# <a id =2></a>
# # Visualization

# %%
categoricalfeatures = ["ChestPainType","RestingECG","Sex","ExerciseAngina","ST_Slope"]
for i in categoricalfeatures:
    ax = plt.subplot(2,3,categoricalfeatures.index(i)+1)
    sns.countplot(x= db_copy[i])
    plt.tight_layout()
plt.show()

# %% [markdown]
# <font color = #8B0000>
# As it can be seen number of males is much bigger than number of females</br>
# Lets see how much these features effect HeartDisease risk
# </font>

# %% [markdown]
# ### The degree to which different categorical features contribute to heart attack risk.

# %%
#Sex
maleHeartDiseaseRate = db_copy[(db_copy["Sex"] == "M") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["Sex"] == "M"].shape[0]
femaleHeartDiseaseRate = db_copy[(db_copy["Sex"] == "F") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["Sex"] == "F"].shape[0]
#chestpaintype
ataChestPainTypeHeartDiseaseRate = db_copy[(db_copy["ChestPainType"] == "ATA") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ChestPainType"] == "ATA"].shape[0]
napChestPainTypeHeartDiseaseRate = db_copy[(db_copy["ChestPainType"] == "NAP") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ChestPainType"] == "NAP"].shape[0]
asyChestPainTypeHeartDiseaseRate = db_copy[(db_copy["ChestPainType"] == "ASY") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ChestPainType"] == "ASY"].shape[0]
taChestPainTypeHeartDiseaseRate = db_copy[(db_copy["ChestPainType"] == "TA") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ChestPainType"] == "TA"].shape[0]
#restingecg
normalRestingEcgRate = db_copy[(db_copy["RestingECG"] == "Normal") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["RestingECG"] == "Normal"].shape[0]
stRestingEcgRate = db_copy[(db_copy["RestingECG"] == "ST") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["RestingECG"] == "ST"].shape[0]
lvhRestingEcgRate = db_copy[(db_copy["RestingECG"] == "LVH") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["RestingECG"] == "LVH"].shape[0]
#ExerciseAngina
NExerciseAnginaRate = db_copy[(db_copy["ExerciseAngina"] == "N") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ExerciseAngina"] == "N"].shape[0]
YExerciseAnginaRate= db_copy[(db_copy["ExerciseAngina"] == "Y") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ExerciseAngina"] == "Y"].shape[0]
#ST_Slope
upStSlopeRate=db_copy[(db_copy["ST_Slope"] == "Up") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ST_Slope"] == "Up"].shape[0]
flatStSlopeRate=db_copy[(db_copy["ST_Slope"] == "Flat") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ST_Slope"] == "Flat"].shape[0]
downStSlopeRate=db_copy[(db_copy["ST_Slope"] == "Down") & (db_copy["HeartDisease"] == 1)].shape[0]/db_copy[db_copy["ST_Slope"] == "Down"].shape[0]

# %%
#Visualization
#rates
genderrate = [maleHeartDiseaseRate,femaleHeartDiseaseRate]
chestpaintyperate = [ataChestPainTypeHeartDiseaseRate,napChestPainTypeHeartDiseaseRate,asyChestPainTypeHeartDiseaseRate,taChestPainTypeHeartDiseaseRate]
restingecgrate = [normalRestingEcgRate,stRestingEcgRate,lvhRestingEcgRate]
exerciseAnginarate = [NExerciseAnginaRate,YExerciseAnginaRate]
stsloperate = [upStSlopeRate,flatStSlopeRate,downStSlopeRate]
rates = [genderrate,chestpaintyperate,restingecgrate,exerciseAnginarate,stsloperate]
#labels
genderlabels = ["male", "female"]
chestpainlabels = ["ata","nap","asy","ta"]
restingecglabels = ["normal","st","lvh"]
exerciseAnginalabels = ["No" , "Yes"]
stslopelabels = ["up","flat","down"]
labels = [genderlabels,chestpainlabels,restingecglabels,exerciseAnginalabels,stslopelabels]
titles = ["Gender","Chest Pain" , "Resting ECG" , "Exercise Angina" , "ST Slope"]


for i in range(0,5):
    plt.subplot(2, 3,i+1)
    plt.title(titles[i])
    plt.pie(rates[i],labels = labels[i],autopct='%.0f%%',colors = sns.color_palette("pastel"))

# %% [markdown]
# Results:
# 1. Males have bigger change to get heart disease
# 2. Those who have Asymptomatic (asy) have bigger change to get heart disease
# 3. Resting ecg values are close to each other so we dont have to think about it
# 4. Those with exercise-induced angina are at a significantly higher risk of having heart disease.
# 5. The higher heart disease rates in the ST slope down and ST slope flat categories compared to ST slope up are likely due to the greater number of individuals with chronic conditions like ischemia or coronary artery disease (CAD), which are more common. ST slope up typically indicates acute conditions like STEMI, which are less frequent and treated quickly, leading to a lower heart disease rate in this group.

# %% [markdown]
# ### The degree to which different continuous features contribute to heart attack risk.

# %%
corrdb = db_copy.loc[:,["Age","RestingBP","Cholesterol","FastingBS","MaxHR","Oldpeak","HeartDisease"]]
sns.heatmap(corrdb.corr(),fmt = ".2f",annot = True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Visualization of most correlated features

# %% [markdown]
# ### MaxHR - Age

# %%
plt.subplot(2,1,1)
sns.set(rc={'figure.figsize':(10, 10)})
sns.lineplot(db_copy["MaxHR"])
plt.subplot(2,1,2)
sns.lineplot(db_copy["Age"])
plt.show()

# %% [markdown]
# <font color = red>As it can be seen when Age decreases MaxHr increases vice versa</font>

# %% [markdown]
# ### MaxHR - Cholesterol

# %%
cholesterol = db_copy[db_copy["Cholesterol"] !=0]["Cholesterol"]
plt.subplot(2,1,1)
sns.set(rc={'figure.figsize':(10, 5)})
sns.lineplot(db_copy["MaxHR"])
plt.subplot(2,1,2)
sns.lineplot(cholesterol)
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ##

# %%
#Split data
y_db = db.loc[:,"HeartDisease"]
db.drop("HeartDisease",inplace = True,axis = 1)
x_db = db

# %%
x_db
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 0      172              N      0.0       Up
# 1      156              N      1.0     Flat
# 2       98              N      0.0       Up
# 3      108              Y      1.5     Flat
# 4      122              N      0.0       Up
# ..     ...            ...      ...      ...
# 913    132              N      1.2     Flat
# 914    141              N      3.4     Flat
# 915    115              Y      1.2     Flat
# 916    174              N      0.0     Flat
# 917    173              N      0.0       Up
#
# [918 rows x 11 columns]

# %% [markdown]
# ## Normalizing

# %% [markdown]
# > Normalizing features ensures that all variables have the same scale, improving model performance, convergence speed, and accuracy, especially for algorithms sensitive to feature magnitude differences.

# %%
featurelist = ["Age","RestingBP","Cholesterol","FastingBS","MaxHR","Oldpeak"]
for i in featurelist:
    x_db[i] = [ (each - np.min(x_db[i])) / (np.max(x_db[i])-np.min(x_db[i]))   for each in x_db[i]]

# %% [markdown]
# ## Label Encoding

# %% [markdown]
# > One-Hot Encoding is a technique that converts categorical variables into a series of binary columns, where each column represents one category, with 1 indicating the presence of that category and 0 otherwise.

# %% [markdown]
# > One-Hot Encoding converts each category into a separate binary column, while Label Encoding assigns a unique integer to each category; One-Hot Encoding is typically used for nominal data, and Label Encoding for ordinal data.

# %%
x_db = pd.get_dummies(x_db , columns = ["ChestPainType","RestingECG","Sex","ExerciseAngina","ST_Slope"],dtype = int)

# %%
#our new database
x_db
# Out:
#           Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# 0    0.244898       0.70     0.479270        0.0  0.788732  0.295455
# 1    0.428571       0.80     0.298507        0.0  0.676056  0.409091
# 2    0.183673       0.65     0.469320        0.0  0.267606  0.295455
# 3    0.408163       0.69     0.354892        0.0  0.338028  0.465909
# 4    0.530612       0.75     0.323383        0.0  0.436620  0.295455
# ..        ...        ...          ...        ...       ...       ...
# 913  0.346939       0.55     0.437811        0.0  0.507042  0.431818
# 914  0.816327       0.72     0.320066        1.0  0.570423  0.681818
# 915  0.591837       0.65     0.217247        0.0  0.387324  0.431818
# 916  0.591837       0.65     0.391376        0.0  0.802817  0.295455
# 917  0.204082       0.69     0.290216        0.0  0.795775  0.295455
#
#      ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# 0                    0                  1                  0
# 1                    0                  0                  1
# 2                    0                  1                  0
# 3                    1                  0                  0
# 4                    0                  0                  1
# ..                 ...                ...                ...
# 913                  0                  0                  0
# 914                  1                  0                  0
# 915                  1                  0                  0
# 916                  0                  1                  0
# 917                  0                  0                  1
#
#      ChestPainType_TA  RestingECG_LVH  RestingECG_Normal  RestingECG_ST  \
# 0                   0               0                  1              0
# 1                   0               0                  1              0
# 2                   0               0                  0              1
# 3                   0               0                  1              0
# 4                   0               0                  1              0
# ..                ...             ...                ...            ...
# 913                 1               0                  1              0
# 914                 0               0                  1              0
# 915                 0               0                  1              0
# 916                 0               1                  0              0
# 917                 0               0                  1              0
#
#      Sex_F  Sex_M  ExerciseAngina_N  ExerciseAngina_Y  ST_Slope_Down  \
# 0        0      1                 1                 0              0
# 1        1      0                 1                 0              0
# 2        0      1                 1                 0              0
# 3        1      0                 0                 1              0
# 4        0      1                 1                 0              0
# ..     ...    ...               ...               ...            ...
# 913      0      1                 1                 0              0
# 914      0      1                 1                 0              0
# 915      0      1                 0                 1              0
# 916      1      0                 1                 0              0
# 917      0      1                 1                 0              0
#
#      ST_Slope_Flat  ST_Slope_Up
# 0                0            1
# 1                1            0
# 2                0            1
# 3                1            0
# 4                0            1
# ..             ...          ...
# 913              1            0
# 914              1            0
# 915              1            0
# 916              1            0
# 917              0            1
#
# [918 rows x 20 columns]

# %% [markdown]
# # Prediction

# %%
#train-test split
x_train , x_test , y_train , y_test = train_test_split(x_db , y_db)

# %%
#with train-test split
logreg = LogisticRegression()
gaussiannb = GaussianNB()
dectree = DecisionTreeClassifier()
randomforest = RandomForestClassifier()
svm = SVC()
knearest = KNeighborsClassifier()
labelList = ["LogReg : " , "GaussianNb : " , "DecTree : ","RandomForest : ","Svm : " , "knearest : "]
classifierList = [logreg , gaussiannb , dectree , randomforest , svm,knearest]
for i in range(0,6):
    classifier = classifierList[i]
    classifier.fit(x_train , y_train)
    print("Score of" ,labelList[i] , classifier.score(x_test,y_test))
# Out:
# Score of LogReg :  0.9
# Score of GaussianNb :  0.8826086956521739
# Score of DecTree :  0.8173913043478261
# Score of RandomForest :  0.8956521739130435
# Score of Svm :  0.8956521739130435
# Score of knearest :  0.8304347826086956

# %% [markdown]
# Actually these scores are going to decrease when working with real data

# %%
#Cross validation
logreg = LogisticRegression()
gaussiannb = GaussianNB()
dectree = DecisionTreeClassifier()
randomforest = RandomForestClassifier()
svm = SVC()
knearest = KNeighborsClassifier()
labelList = ["LogReg : " , "GaussianNb : " , "DecTree : ","RandomForest : ","Svm : ", "knearest : "]
classifierList = [logreg , gaussiannb , dectree , randomforest , svm,knearest]
for i in range(0,6):
    classifier = classifierList[i]
    classifier.fit(x_train , y_train)
    scores = cross_val_score(classifier, x_train , y_train,n_jobs = 5)
    print("Score of" ,labelList[i] , np.mean(scores))
# Out:
# Score of LogReg :  0.8488522162276524
# Score of GaussianNb :  0.8357770020099439
# Score of DecTree :  0.7906802073415848
# Score of RandomForest :  0.8488839521844916
# Score of Svm :  0.8387178673437005
# Score of knearest :  0.8314291759229875

# %% [markdown]
# As it can be seen cross-validation-score are lower than train-test split score

# %%
#HyperParameterTuning
params = [
    
     {
         #logisticregression
        "C" : [0.01 , 0.1 , 1 , 10 , 100],
        "max_iter" : [100 , 150 , 200],
        "penalty" : ["l1" , "l2"],
        "solver" : ["lbfgs", "liblinear", "newton-cg"],
    },
    
    {
        #decisiontree
        "min_samples_leaf" : [1 , 5 , 10],
        "min_samples_split" : [3 , 5 , 10 , 20],
        "criterion" : ["gini" , "entropy"],
        },
    {
        #randomforest
    # cause it takes too much time to try all the different parameter options I used the 
    # most accurate parameters that I found
       'criterion': ['entropy'],
         'min_samples_split': [20],
         'n_estimators': [50],
        
    },
    #naive - bayes
    {
        "var_smoothing" : [1e-9 , 1e-8 , 1e-7]
    } ,
    #knearest
    {
        "n_neighbors":[3,5,10,20,30],
    "weights":["uniform","distance"],
    "metric":["eucladian","manhattan"],
    },
#svc
{
                    "C":[1,10,50,300,500],
                  "gamma":[0.1,0.01,0.001,0.0001,1],
    
},
]

# %%
X_train,X_val,Y_train,Y_val = train_test_split(x_train,y_train)
logreg = LogisticRegression()
dectree = DecisionTreeClassifier()
randforest = RandomForestClassifier()
gaussiannb = GaussianNB()
knearest = KNeighborsClassifier()
svc = SVC()
modellist = {
   'logreg': logreg,
 'dectree': dectree,
 'randforest': randforest,
 'gaussiannb': gaussiannb,
 'knearest': knearest,
 'svc': svc,}
i = 0
for key , value in modellist.items():
   clf = GridSearchCV(value , params[i])
   clf.fit(X_train,Y_train)
   print(key,": ", clf.score(X_val,Y_val)) 
   i+=1
# Out:
# logreg :  0.8255813953488372
# dectree :  0.813953488372093
# randforest :  0.8313953488372093
# gaussiannb :  0.8197674418604651
# knearest :  0.8372093023255814
# svc :  0.8197674418604651

# %% [markdown]
# <font color ="blue">
# First of all we split our train data to second train data and validation data </br>
# we used validation data as test data to find best parameters
# </font>

# %% [markdown]
# Sklearn cross validation doc: https://scikit-learn.org/1.5/modules/cross_validation.html

# %% [markdown]
# <font color = "blue">
# Cross validation score of our models with real test data
# </font>

# %%
i = 0
for key , value in modellist.items():
   clf = GridSearchCV(value , params[i])
   clf.fit(X_train,Y_train)
   print(key,": ", clf.score(x_test,y_test)) 
   i+=1
# Out:
# logreg :  0.9043478260869565
# dectree :  0.8
# randforest :  0.9
# gaussiannb :  0.8826086956521739
# knearest :  0.9
# svc :  0.8826086956521739

# %% [markdown]
# ## Prediction with artifical neural networks

# %% [markdown]
# <font color = "blue">We are gonna use keras </br> Keras Documents : https://keras.io/api/ </font>

# %%
# !pip install tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import Input
from tensorflow.keras.optimizers import Adam
model = Sequential()
model.add(Input(shape = (20,))) #we have 20 features thats why our input layer has 20 neurons
model.add(Dense(activation = "relu" , units = 32))
model.add(Dense(activation = "relu" , units = 32))
model.add(Dense(activation = "relu" , units = 8))
model.add(Dense(activation = "softmax" , units = 2))
model.compile(metrics = ["accuracy"] , optimizer = Adam(learning_rate = 0.0001) , loss = "sparse_categorical_crossentropy")
our_model = model.fit(x = x_train , y = y_train , batch_size = 30 , epochs = 200 ,shuffle = True , verbose = 2,validation_data=(x_test, y_test))
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (74.1.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.5.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.8.0)
# Requirement already satisfied: namex in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# Epoch 1/200
# 23/23 - 1s - 46ms/step - accuracy: 0.4535 - loss: 0.8494 - val_accuracy: 0.4261 - val_loss: 0.8555
# Epoch 2/200
# 23/23 - 0s - 3ms/step - accuracy: 0.4535 - loss: 0.8094 - val_accuracy: 0.4261 - val_loss: 0.8158
# Epoch 3/200
# 23/23 - 0s - 3ms/step - accuracy: 0.4535 - loss: 0.7764 - val_accuracy: 0.4261 - val_loss: 0.7810
# Epoch 4/200
# 23/23 - 0s - 3ms/step - accuracy: 0.4535 - loss: 0.7478 - val_accuracy: 0.4261 - val_loss: 0.7516
# Epoch 5/200
# 23/23 - 0s - 3ms/step - accuracy: 0.4535 - loss: 0.7253 - val_accuracy: 0.4261 - val_loss: 0.7316
# Epoch 6/200
# 23/23 - 0s - 3ms/step - accuracy: 0.4549 - loss: 0.7095 - val_accuracy: 0.4304 - val_loss: 0.7151
# Epoch 7/200
# 23/23 - 0s - 3ms/step - accuracy: 0.4593 - loss: 0.6964 - val_accuracy: 0.4261 - val_loss: 0.7010
# Epoch 8/200
# 23/23 - 0s - 3ms/step - accuracy: 0.4622 - loss: 0.6843 - val_accuracy: 0.4348 - val_loss: 0.6887
# Epoch 9/200
# 23/23 - 0s - 3ms/step - accuracy: 0.5073 - loss: 0.6735 - val_accuracy: 0.5435 - val_loss: 0.6773
# Epoch 10/200
# 23/23 - 0s - 3ms/step - accuracy: 0.6308 - loss: 0.6634 - val_accuracy: 0.6478 - val_loss: 0.6658
# Epoch 11/200
# 23/23 - 0s - 4ms/step - accuracy: 0.7253 - loss: 0.6533 - val_accuracy: 0.6957 - val_loss: 0.6554
# Epoch 12/200
# 23/23 - 0s - 3ms/step - accuracy: 0.7427 - loss: 0.6439 - val_accuracy: 0.7304 - val_loss: 0.6452
# Epoch 13/200
# 23/23 - 0s - 3ms/step - accuracy: 0.7863 - loss: 0.6344 - val_accuracy: 0.7696 - val_loss: 0.6351
# Epoch 14/200
# 23/23 - 0s - 4ms/step - accuracy: 0.7994 - loss: 0.6250 - val_accuracy: 0.7826 - val_loss: 0.6253
# Epoch 15/200
# 23/23 - 0s - 4ms/step - accuracy: 0.7980 - loss: 0.6154 - val_accuracy: 0.7913 - val_loss: 0.6148
# Epoch 16/200
# 23/23 - 0s - 4ms/step - accuracy: 0.8067 - loss: 0.6050 - val_accuracy: 0.8174 - val_loss: 0.6041
# Epoch 17/200
# 23/23 - 0s - 4ms/step - accuracy: 0.8140 - loss: 0.5937 - val_accuracy: 0.8217 - val_loss: 0.5922
# Epoch 18/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8140 - loss: 0.5807 - val_accuracy: 0.8087 - val_loss: 0.5788
# Epoch 19/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8212 - loss: 0.5667 - val_accuracy: 0.8087 - val_loss: 0.5643
# Epoch 20/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8256 - loss: 0.5518 - val_accuracy: 0.8130 - val_loss: 0.5490
# Epoch 21/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8343 - loss: 0.5365 - val_accuracy: 0.8087 - val_loss: 0.5343
# Epoch 22/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8343 - loss: 0.5208 - val_accuracy: 0.8130 - val_loss: 0.5187
# Epoch 23/200
# 23/23 - 0s - 4ms/step - accuracy: 0.8445 - loss: 0.5036 - val_accuracy: 0.8130 - val_loss: 0.5005
# Epoch 24/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8459 - loss: 0.4861 - val_accuracy: 0.8174 - val_loss: 0.4831
# Epoch 25/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8445 - loss: 0.4702 - val_accuracy: 0.8174 - val_loss: 0.4661
# Epoch 26/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8459 - loss: 0.4566 - val_accuracy: 0.8261 - val_loss: 0.4506
# Epoch 27/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8474 - loss: 0.4443 - val_accuracy: 0.8348 - val_loss: 0.4380
# Epoch 28/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8517 - loss: 0.4338 - val_accuracy: 0.8348 - val_loss: 0.4251
# Epoch 29/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8532 - loss: 0.4243 - val_accuracy: 0.8522 - val_loss: 0.4136
# Epoch 30/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8547 - loss: 0.4159 - val_accuracy: 0.8522 - val_loss: 0.4045
# Epoch 31/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8561 - loss: 0.4088 - val_accuracy: 0.8522 - val_loss: 0.3951
# Epoch 32/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8561 - loss: 0.4021 - val_accuracy: 0.8565 - val_loss: 0.3876
# Epoch 33/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8561 - loss: 0.3966 - val_accuracy: 0.8565 - val_loss: 0.3799
# Epoch 34/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8547 - loss: 0.3913 - val_accuracy: 0.8565 - val_loss: 0.3742
# Epoch 35/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8547 - loss: 0.3868 - val_accuracy: 0.8565 - val_loss: 0.3686
# Epoch 36/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8561 - loss: 0.3826 - val_accuracy: 0.8609 - val_loss: 0.3636
# Epoch 37/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8605 - loss: 0.3787 - val_accuracy: 0.8609 - val_loss: 0.3572
# Epoch 38/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8619 - loss: 0.3755 - val_accuracy: 0.8522 - val_loss: 0.3547
# Epoch 39/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8619 - loss: 0.3724 - val_accuracy: 0.8609 - val_loss: 0.3496
# Epoch 40/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8619 - loss: 0.3697 - val_accuracy: 0.8652 - val_loss: 0.3475
# Epoch 41/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8619 - loss: 0.3672 - val_accuracy: 0.8783 - val_loss: 0.3440
# Epoch 42/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8634 - loss: 0.3650 - val_accuracy: 0.8783 - val_loss: 0.3421
# Epoch 43/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3628 - val_accuracy: 0.8739 - val_loss: 0.3376
# Epoch 44/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8634 - loss: 0.3613 - val_accuracy: 0.8783 - val_loss: 0.3372
# Epoch 45/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8634 - loss: 0.3593 - val_accuracy: 0.8783 - val_loss: 0.3344
# Epoch 46/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8619 - loss: 0.3577 - val_accuracy: 0.8783 - val_loss: 0.3305
# Epoch 47/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8605 - loss: 0.3568 - val_accuracy: 0.8783 - val_loss: 0.3312
# Epoch 48/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8619 - loss: 0.3547 - val_accuracy: 0.8870 - val_loss: 0.3282
# Epoch 49/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8619 - loss: 0.3534 - val_accuracy: 0.8870 - val_loss: 0.3265
# Epoch 50/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3521 - val_accuracy: 0.8870 - val_loss: 0.3267
# Epoch 51/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3509 - val_accuracy: 0.8870 - val_loss: 0.3257
# Epoch 52/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8605 - loss: 0.3500 - val_accuracy: 0.8870 - val_loss: 0.3251
# Epoch 53/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8634 - loss: 0.3495 - val_accuracy: 0.8913 - val_loss: 0.3211
# Epoch 54/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8634 - loss: 0.3480 - val_accuracy: 0.8913 - val_loss: 0.3226
# Epoch 55/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8634 - loss: 0.3470 - val_accuracy: 0.8913 - val_loss: 0.3217
# Epoch 56/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8619 - loss: 0.3463 - val_accuracy: 0.8913 - val_loss: 0.3198
# Epoch 57/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8634 - loss: 0.3458 - val_accuracy: 0.8870 - val_loss: 0.3207
# Epoch 58/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3447 - val_accuracy: 0.8870 - val_loss: 0.3195
# Epoch 59/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8619 - loss: 0.3441 - val_accuracy: 0.8913 - val_loss: 0.3178
# Epoch 60/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3435 - val_accuracy: 0.8913 - val_loss: 0.3175
# Epoch 61/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3429 - val_accuracy: 0.8870 - val_loss: 0.3189
# Epoch 62/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3422 - val_accuracy: 0.8913 - val_loss: 0.3161
# Epoch 63/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3415 - val_accuracy: 0.8913 - val_loss: 0.3178
# Epoch 64/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3410 - val_accuracy: 0.8913 - val_loss: 0.3161
# Epoch 65/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3403 - val_accuracy: 0.8913 - val_loss: 0.3168
# Epoch 66/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8634 - loss: 0.3399 - val_accuracy: 0.8913 - val_loss: 0.3150
# Epoch 67/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3393 - val_accuracy: 0.8870 - val_loss: 0.3143
# Epoch 68/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3387 - val_accuracy: 0.8913 - val_loss: 0.3159
# Epoch 69/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3379 - val_accuracy: 0.8913 - val_loss: 0.3150
# Epoch 70/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3375 - val_accuracy: 0.8913 - val_loss: 0.3149
# Epoch 71/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8634 - loss: 0.3369 - val_accuracy: 0.8870 - val_loss: 0.3135
# Epoch 72/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3365 - val_accuracy: 0.8913 - val_loss: 0.3132
# Epoch 73/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3361 - val_accuracy: 0.8870 - val_loss: 0.3130
# Epoch 74/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3362 - val_accuracy: 0.8870 - val_loss: 0.3124
# Epoch 75/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3351 - val_accuracy: 0.8913 - val_loss: 0.3136
# Epoch 76/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3347 - val_accuracy: 0.8870 - val_loss: 0.3143
# Epoch 77/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3342 - val_accuracy: 0.8870 - val_loss: 0.3128
# Epoch 78/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3337 - val_accuracy: 0.8870 - val_loss: 0.3130
# Epoch 79/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3332 - val_accuracy: 0.8826 - val_loss: 0.3126
# Epoch 80/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3331 - val_accuracy: 0.8870 - val_loss: 0.3116
# Epoch 81/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3330 - val_accuracy: 0.8870 - val_loss: 0.3107
# Epoch 82/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3319 - val_accuracy: 0.8826 - val_loss: 0.3121
# Epoch 83/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3317 - val_accuracy: 0.8826 - val_loss: 0.3125
# Epoch 84/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3313 - val_accuracy: 0.8826 - val_loss: 0.3128
# Epoch 85/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3309 - val_accuracy: 0.8826 - val_loss: 0.3121
# Epoch 86/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3304 - val_accuracy: 0.8826 - val_loss: 0.3117
# Epoch 87/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3303 - val_accuracy: 0.8826 - val_loss: 0.3106
# Epoch 88/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3302 - val_accuracy: 0.8826 - val_loss: 0.3104
# Epoch 89/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8648 - loss: 0.3292 - val_accuracy: 0.8826 - val_loss: 0.3104
# Epoch 90/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3291 - val_accuracy: 0.8826 - val_loss: 0.3110
# Epoch 91/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3284 - val_accuracy: 0.8826 - val_loss: 0.3110
# Epoch 92/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3280 - val_accuracy: 0.8826 - val_loss: 0.3114
# Epoch 93/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3279 - val_accuracy: 0.8783 - val_loss: 0.3105
# Epoch 94/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3273 - val_accuracy: 0.8826 - val_loss: 0.3110
# Epoch 95/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3270 - val_accuracy: 0.8783 - val_loss: 0.3101
# Epoch 96/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3267 - val_accuracy: 0.8783 - val_loss: 0.3103
# Epoch 97/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3264 - val_accuracy: 0.8783 - val_loss: 0.3112
# Epoch 98/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3261 - val_accuracy: 0.8826 - val_loss: 0.3125
# Epoch 99/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3253 - val_accuracy: 0.8783 - val_loss: 0.3104
# Epoch 100/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3249 - val_accuracy: 0.8783 - val_loss: 0.3097
# Epoch 101/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3246 - val_accuracy: 0.8783 - val_loss: 0.3098
# Epoch 102/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3245 - val_accuracy: 0.8783 - val_loss: 0.3103
# Epoch 103/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3241 - val_accuracy: 0.8783 - val_loss: 0.3080
# Epoch 104/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3239 - val_accuracy: 0.8783 - val_loss: 0.3112
# Epoch 105/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3232 - val_accuracy: 0.8783 - val_loss: 0.3097
# Epoch 106/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3229 - val_accuracy: 0.8783 - val_loss: 0.3096
# Epoch 107/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3226 - val_accuracy: 0.8783 - val_loss: 0.3097
# Epoch 108/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3225 - val_accuracy: 0.8783 - val_loss: 0.3086
# Epoch 109/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3219 - val_accuracy: 0.8783 - val_loss: 0.3090
# Epoch 110/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3215 - val_accuracy: 0.8783 - val_loss: 0.3090
# Epoch 111/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3217 - val_accuracy: 0.8783 - val_loss: 0.3076
# Epoch 112/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3211 - val_accuracy: 0.8783 - val_loss: 0.3099
# Epoch 113/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3209 - val_accuracy: 0.8783 - val_loss: 0.3109
# Epoch 114/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3206 - val_accuracy: 0.8783 - val_loss: 0.3078
# Epoch 115/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3202 - val_accuracy: 0.8783 - val_loss: 0.3078
# Epoch 116/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3197 - val_accuracy: 0.8783 - val_loss: 0.3082
# Epoch 117/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8663 - loss: 0.3195 - val_accuracy: 0.8783 - val_loss: 0.3087
# Epoch 118/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3195 - val_accuracy: 0.8783 - val_loss: 0.3076
# Epoch 119/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3189 - val_accuracy: 0.8783 - val_loss: 0.3108
# Epoch 120/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3185 - val_accuracy: 0.8783 - val_loss: 0.3091
# Epoch 121/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3180 - val_accuracy: 0.8783 - val_loss: 0.3091
# Epoch 122/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3181 - val_accuracy: 0.8783 - val_loss: 0.3078
# Epoch 123/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3174 - val_accuracy: 0.8783 - val_loss: 0.3084
# Epoch 124/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3171 - val_accuracy: 0.8783 - val_loss: 0.3080
# Epoch 125/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3170 - val_accuracy: 0.8783 - val_loss: 0.3076
# Epoch 126/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3167 - val_accuracy: 0.8783 - val_loss: 0.3091
# Epoch 127/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3163 - val_accuracy: 0.8783 - val_loss: 0.3080
# Epoch 128/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3161 - val_accuracy: 0.8826 - val_loss: 0.3070
# Epoch 129/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3156 - val_accuracy: 0.8826 - val_loss: 0.3077
# Epoch 130/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3153 - val_accuracy: 0.8783 - val_loss: 0.3086
# Epoch 131/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3150 - val_accuracy: 0.8826 - val_loss: 0.3074
# Epoch 132/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3149 - val_accuracy: 0.8826 - val_loss: 0.3071
# Epoch 133/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3144 - val_accuracy: 0.8783 - val_loss: 0.3087
# Epoch 134/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3143 - val_accuracy: 0.8826 - val_loss: 0.3078
# Epoch 135/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3140 - val_accuracy: 0.8826 - val_loss: 0.3073
# Epoch 136/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3135 - val_accuracy: 0.8783 - val_loss: 0.3079
# Epoch 137/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3134 - val_accuracy: 0.8826 - val_loss: 0.3072
# Epoch 138/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3132 - val_accuracy: 0.8826 - val_loss: 0.3069
# Epoch 139/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3127 - val_accuracy: 0.8826 - val_loss: 0.3078
# Epoch 140/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3124 - val_accuracy: 0.8826 - val_loss: 0.3071
# Epoch 141/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3122 - val_accuracy: 0.8826 - val_loss: 0.3078
# Epoch 142/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3119 - val_accuracy: 0.8783 - val_loss: 0.3082
# Epoch 143/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3117 - val_accuracy: 0.8826 - val_loss: 0.3056
# Epoch 144/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3114 - val_accuracy: 0.8826 - val_loss: 0.3072
# Epoch 145/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3116 - val_accuracy: 0.8783 - val_loss: 0.3081
# Epoch 146/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3108 - val_accuracy: 0.8826 - val_loss: 0.3065
# Epoch 147/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3107 - val_accuracy: 0.8783 - val_loss: 0.3073
# Epoch 148/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3103 - val_accuracy: 0.8783 - val_loss: 0.3077
# Epoch 149/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3103 - val_accuracy: 0.8826 - val_loss: 0.3057
# Epoch 150/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3098 - val_accuracy: 0.8826 - val_loss: 0.3064
# Epoch 151/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3097 - val_accuracy: 0.8826 - val_loss: 0.3061
# Epoch 152/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3095 - val_accuracy: 0.8826 - val_loss: 0.3057
# Epoch 153/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3090 - val_accuracy: 0.8783 - val_loss: 0.3090
# Epoch 154/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3094 - val_accuracy: 0.8783 - val_loss: 0.3063
# Epoch 155/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3087 - val_accuracy: 0.8783 - val_loss: 0.3081
# Epoch 156/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3084 - val_accuracy: 0.8783 - val_loss: 0.3063
# Epoch 157/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3077 - val_accuracy: 0.8826 - val_loss: 0.3049
# Epoch 158/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3076 - val_accuracy: 0.8783 - val_loss: 0.3063
# Epoch 159/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8677 - loss: 0.3072 - val_accuracy: 0.8783 - val_loss: 0.3064
# Epoch 160/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8706 - loss: 0.3069 - val_accuracy: 0.8826 - val_loss: 0.3052
# Epoch 161/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3067 - val_accuracy: 0.8783 - val_loss: 0.3059
# Epoch 162/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8706 - loss: 0.3064 - val_accuracy: 0.8783 - val_loss: 0.3060
# Epoch 163/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3063 - val_accuracy: 0.8783 - val_loss: 0.3058
# Epoch 164/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8692 - loss: 0.3060 - val_accuracy: 0.8783 - val_loss: 0.3071
# Epoch 165/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8706 - loss: 0.3056 - val_accuracy: 0.8826 - val_loss: 0.3049
# Epoch 166/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8706 - loss: 0.3054 - val_accuracy: 0.8826 - val_loss: 0.3053
# Epoch 167/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8721 - loss: 0.3054 - val_accuracy: 0.8783 - val_loss: 0.3064
# Epoch 168/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8721 - loss: 0.3048 - val_accuracy: 0.8783 - val_loss: 0.3060
# Epoch 169/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8721 - loss: 0.3046 - val_accuracy: 0.8783 - val_loss: 0.3050
# Epoch 170/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8721 - loss: 0.3044 - val_accuracy: 0.8783 - val_loss: 0.3064
# Epoch 171/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8735 - loss: 0.3040 - val_accuracy: 0.8783 - val_loss: 0.3059
# Epoch 172/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8706 - loss: 0.3039 - val_accuracy: 0.8783 - val_loss: 0.3056
# Epoch 173/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8735 - loss: 0.3034 - val_accuracy: 0.8783 - val_loss: 0.3051
# Epoch 174/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8735 - loss: 0.3032 - val_accuracy: 0.8783 - val_loss: 0.3058
# Epoch 175/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8765 - loss: 0.3032 - val_accuracy: 0.8783 - val_loss: 0.3071
# Epoch 176/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8735 - loss: 0.3027 - val_accuracy: 0.8783 - val_loss: 0.3059
# Epoch 177/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8735 - loss: 0.3027 - val_accuracy: 0.8783 - val_loss: 0.3052
# Epoch 178/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8735 - loss: 0.3021 - val_accuracy: 0.8783 - val_loss: 0.3046
# Epoch 179/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8794 - loss: 0.3022 - val_accuracy: 0.8739 - val_loss: 0.3070
# Epoch 180/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8765 - loss: 0.3016 - val_accuracy: 0.8870 - val_loss: 0.3038
# Epoch 181/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8765 - loss: 0.3015 - val_accuracy: 0.8739 - val_loss: 0.3053
# Epoch 182/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8765 - loss: 0.3009 - val_accuracy: 0.8739 - val_loss: 0.3057
# Epoch 183/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8765 - loss: 0.3010 - val_accuracy: 0.8870 - val_loss: 0.3042
# Epoch 184/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8779 - loss: 0.3006 - val_accuracy: 0.8826 - val_loss: 0.3046
# Epoch 185/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8765 - loss: 0.3001 - val_accuracy: 0.8739 - val_loss: 0.3063
# Epoch 186/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8779 - loss: 0.3000 - val_accuracy: 0.8739 - val_loss: 0.3060
# Epoch 187/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8779 - loss: 0.2997 - val_accuracy: 0.8739 - val_loss: 0.3060
# Epoch 188/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8794 - loss: 0.2996 - val_accuracy: 0.8870 - val_loss: 0.3042
# Epoch 189/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8794 - loss: 0.2993 - val_accuracy: 0.8783 - val_loss: 0.3048
# Epoch 190/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8765 - loss: 0.2990 - val_accuracy: 0.8739 - val_loss: 0.3051
# Epoch 191/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8765 - loss: 0.2986 - val_accuracy: 0.8739 - val_loss: 0.3053
# Epoch 192/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8765 - loss: 0.2984 - val_accuracy: 0.8783 - val_loss: 0.3052
# Epoch 193/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8779 - loss: 0.2981 - val_accuracy: 0.8739 - val_loss: 0.3063
# Epoch 194/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8765 - loss: 0.2978 - val_accuracy: 0.8783 - val_loss: 0.3051
# Epoch 195/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8779 - loss: 0.2977 - val_accuracy: 0.8739 - val_loss: 0.3056
# Epoch 196/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8779 - loss: 0.2973 - val_accuracy: 0.8739 - val_loss: 0.3057
# Epoch 197/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8794 - loss: 0.2970 - val_accuracy: 0.8826 - val_loss: 0.3043
# Epoch 198/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8808 - loss: 0.2969 - val_accuracy: 0.8826 - val_loss: 0.3045
# Epoch 199/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8794 - loss: 0.2967 - val_accuracy: 0.8870 - val_loss: 0.3037
# Epoch 200/200
# 23/23 - 0s - 3ms/step - accuracy: 0.8794 - loss: 0.2962 - val_accuracy: 0.8739 - val_loss: 0.3059

# %%
# Save the model in SavedModel format
model.save('my_model.keras')

# %% [markdown]
# <h3>With thousand iteration we can get %93 acc rate but we dont know that our data is overfitted to train data</br>
# </br>
# To learn it:</h3>

# %%
train_acc = our_model.history["accuracy"]
test_acc = our_model.history["val_accuracy"]

#first plot
plt.subplot(2,1,1)
plt.title("Train Accuracy")
plt.plot(train_acc)
ax1 = plt.gca()
ax1.set_facecolor('black') 
ax1.grid(True , color = "#A9A9A9")
#second plot
plt.subplot(2,1,2)
plt.title("Test Accuracy")
plt.plot(test_acc,color = "green")
ax2 = plt.gca()
ax2.set_facecolor('black') 
ax2.grid(True , color = "#A9A9A9")


plt.tight_layout()
plt.show()

# %% [markdown]
# <font color = "blue">
# <h4>
# If the train accuracy was increasing while the test accuracy was decreasing, we could have said that our model was overfitting. However, both graphs are quite similar, and as we can see, after approximately 100 epochs, there was almost no further improvement in the graph, which indicates that 1000 epochs would have been unnecessary.
#
# </h4>
# </font

# %% [markdown]
# ## Thank You for Reading!
#
# I sincerely appreciate your time and attention while going through this notebook. I hope you found the content helpful and insightful. If you have any questions or feedback, feel free to reach out!
#
# Happy learning and coding! 🚀

# %%
print(model.input_shape)
# Out:
# (None, 20)

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (0.46.0)
# Requirement already satisfied: numpy in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from shap) (1.14.1)
# Requirement already satisfied: scikit-learn in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from shap) (1.5.1)
# Requirement already satisfied: pandas in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from shap) (2.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from shap) (4.66.5)
# Requirement already satisfied: packaging>20.9 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from shap) (24.1)
# Requirement already satisfied: slicer==0.0.8 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from shap) (0.61.0)
# Requirement already satisfied: cloudpickle in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from shap) (3.1.1)
# Requirement already satisfied: colorama in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from numba->shap) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\saran\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import shap
import numpy as np
import matplotlib.pyplot as plt

# %%
# Select a background dataset (usually a subset of the training data)
# Correct way to select random rows in a DataFrame
background = x_train.iloc[np.random.choice(x_train.shape[0], 100, replace=False)]


# Initialize the SHAP DeepExplainer
explainer = shap.DeepExplainer(model, background)

# %%
# Explain predictions on the test set
shap_values = explainer.shap_values(x_test.values)  # Convert DataFrame to NumPy array

# %%
  # Ensure this line runs without errors

# Plot SHAP summary
shap.summary_plot(shap_values[0], x_test.values, feature_names=[f'Feature_{i}' for i in range(20)])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[54], line 4
#       1 # Ensure this line runs without errors
#       2
#       3 # Plot SHAP summary
# ----> 4 shap.summary_plot(shap_values[0], x_test.values, feature_names=[f'Feature_{i}' for i in range(20)])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\plots\_beeswarm.py:543, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale)
#     540         assert False, shape_msg + " Perhaps the extra column in the shap_values matrix is the " \
#     541                       "constant offset? Of so just pass shap_values[:,:-1]."
#     542     else:
# --> 543         assert num_features == features.shape[1], shape_msg
#     545 if feature_names is None:
#     546     feature_names = np.array([labels['FEATURE'] % str(i) for i in range(num_features)])
#
# AssertionError: The shape of the shap_values matrix does not match the shape of the provided data matrix.

# %%
print(f"SHAP values shape: {shap_values[0].shape}")
print(f"x_test shape: {x_test.shape}")
# Out:
# SHAP values shape: (20, 2)
# x_test shape: (230, 20)

# %%
print(shap_values)
# Out:
# [[[ 9.69784969e-01 -9.69785190e-01]
#   [ 5.31434721e-01 -5.31434951e-01]
#   [-6.31870138e-01  6.31870454e-01]
#   ...
#   [-1.07172893e+00  1.07172961e+00]
#   [ 5.22302541e-01 -5.22302311e-01]
#   [-9.86136582e-02  9.86136574e-02]]
#
#  [[ 1.79977859e-02 -1.79977869e-02]
#   [ 1.12522649e-03 -1.12522735e-03]
#   [ 3.70025872e-03 -3.70025851e-03]
#   ...
#   [-4.76887129e-03  4.76887140e-03]
#   [-6.79624877e-02  6.79624950e-02]
#   [-1.42394022e-01  1.42394028e-01]]
#
#  [[ 6.96163155e-03 -6.96163112e-03]
#   [ 3.00308026e-03 -3.00308007e-03]
#   [ 5.61100787e-03 -5.61100603e-03]
#   ...
#   [-2.59143695e-03  2.59143732e-03]
#   [-3.44549877e-02  3.44549839e-02]
#   [-3.92192622e-02  3.92192698e-02]]
#
#  ...
#
#  [[-2.42259213e-02  2.42259188e-02]
#   [ 2.16045807e-03 -2.16045813e-03]
#   [ 1.62749597e-02 -1.62749572e-02]
#   ...
#   [-8.87317242e-03  8.87317144e-03]
#   [ 6.48208152e-03 -6.48208195e-03]
#   [-9.74674210e-02  9.74674232e-02]]
#
#  [[-2.81456979e-02  2.81457296e-02]
#   [-4.28374189e-03  4.28375150e-03]
#   [-5.28516209e-02  5.28516238e-02]
#   ...
#   [-6.39276000e-03  6.39275938e-03]
#   [-7.01064429e-02  7.01063890e-02]
#   [-1.18007566e-01  1.18007541e-01]]
#
#  [[ 3.39763960e-03 -3.39763748e-03]
#   [-6.99296657e-03  6.99296757e-03]
#   [-1.24403466e-01  1.24403467e-01]
#   ...
#   [ 6.69097342e-05 -6.69086119e-05]
#   [ 1.53207019e-01 -1.53207008e-01]
#   [ 3.21918641e-01 -3.21918646e-01]]]

# %%
# Correct background selection
background = x_train.sample(100, random_state=42).values  # Ensure random samples without index issues

# Reinitialize the SHAP explainer
explainer = shap.DeepExplainer(model, background)

# Compute SHAP values for the full x_test
shap_values = explainer.shap_values(x_test.values)

# Final summary plot
shap.summary_plot(shap_values[0], x_test.values, feature_names=[f'Feature_{i}' for i in range(20)])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[57], line 11
#       8 shap_values = explainer.shap_values(x_test.values)
#      10 # Final summary plot
# ---> 11 shap.summary_plot(shap_values[0], x_test.values, feature_names=[f'Feature_{i}' for i in range(20)])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\plots\_beeswarm.py:543, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale)
#     540         assert False, shape_msg + " Perhaps the extra column in the shap_values matrix is the " \
#     541                       "constant offset? Of so just pass shap_values[:,:-1]."
#     542     else:
# --> 543         assert num_features == features.shape[1], shape_msg
#     545 if feature_names is None:
#     546     feature_names = np.array([labels['FEATURE'] % str(i) for i in range(num_features)])
#
# AssertionError: The shape of the shap_values matrix does not match the shape of the provided data matrix.

# %%
# Verify prediction shape
preds = model.predict(x_test)
print(preds.shape)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# (230, 2)

# %%
import shap
import numpy as np

# Correct background data
background = x_train.sample(100, random_state=42).values  # 100 random samples

# Initialize SHAP DeepExplainer
explainer = shap.DeepExplainer(model, background)

# Compute SHAP values for the full test set
shap_values = explainer.shap_values(x_test.values)

# Check SHAP values shape
print(f'SHAP values shape: {np.array(shap_values).shape}')
# Out:
# SHAP values shape: (230, 20, 2)

# %%
# Use actual column names from x_test
feature_names = x_test.columns.tolist()

# Summary plot for Class 0
shap.summary_plot(shap_values[:, :, 0], x_test, feature_names=feature_names)

# Summary plot for Class 1
shap.summary_plot(shap_values[:, :, 1], x_test, feature_names=feature_names)

# %%
# For a specific feature, e.g., 'feature_0'
shap.dependence_plot('Cholesterol', shap_values[:, :, 1], x_test, feature_names=feature_names)

# %%
import shap
import numpy as np

# Convert expected_value to NumPy if it's a Tensor
base_value = explainer.expected_value[1]
if hasattr(base_value, 'numpy'):
    base_value = base_value.numpy()  # Convert TensorFlow tensor to NumPy

# Convert SHAP values to NumPy if they're tensors
shap_vals = shap_values[0, :, 1]
if hasattr(shap_vals, 'numpy'):
    shap_vals = shap_vals.numpy()  # Convert TensorFlow tensor to NumPy

# Convert input data to NumPy
input_data = x_test.iloc[0].to_numpy()

# Initialize JavaScript visualization
shap.initjs()

# Force Plot
shap.force_plot(base_value, shap_vals, input_data, feature_names=feature_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i10UJ5LQ6A7NQ5VO04FEW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5760852694511414, "outValue": 0.9199889797764561, "link": "identity", "featureNames": ["Age", "RestingBP", "Cholesterol", "FastingBS", "MaxHR", "Oldpeak", "ChestPainType_ASY", "ChestPainType_ATA", "ChestPainType_NAP", "ChestPainType_TA", "RestingECG_LVH", "RestingECG_Normal", "RestingECG_ST", "Sex_F", "Sex_M", "ExerciseAngina_N", "ExerciseAngina_Y", "ST_Slope_Down", "ST_Slope_Flat", "ST_Slope_Up"], "features": {"0": {"effect": 0.0016752782235948363, "value": 0.5714285714285714}, "1": {"effect": 9.327472813893068e-05, "value": 1.0}, "2": {"effect": -0.024305526062747326, "value": 0.47761194029850745}, "3": {"effect": 0.07049435576424003, "value": 1.0}, "4": {"effect": 0.005115702086310504, "value": 0.5140845070422535}, "5": {"effect": 0.03879028816792097, "value": 0.7499999999999999}, "6": {"effect": 0.10276198282837867, "value": 1.0}, "7": {"effect": 0.016390539184212686, "value": 0.0}, "8": {"effect": 0.04941308528184891, "value": 0.0}, "9": {"effect": 0.014832579884678126, "value": 0.0}, "10": {"effect": 0.035062425683718174, "value": 1.0}, "11": {"effect": -0.06100044866092503, "value": 0.0}, "12": {"effect": -0.010233751367777585, "value": 0.0}, "13": {"effect": -0.056519798226072455, "value": 1.0}, "14": {"effect": -0.060884670447558166, "value": 0.0}, "15": {"effect": 0.030667909770272672, "value": 0.0}, "16": {"effect": 0.12673948284238576, "value": 1.0}, "17": {"effect": -0.020597182414494455, "value": 1.0}, "18": {"effect": 0.007108556202147156, "value": 0.0}, "19": {"effect": 0.07829962685704231, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i10UJ5LQ6A7NQ5VO04FEW')
#   );
# </script>

# %%
import shap
import numpy as np

# Check shapes before proceeding
print("SHAP Values Shape:", np.array(shap_values).shape)
print("x_test Shape:", x_test.shape)

# If classification, select one class
if len(np.array(shap_values).shape) == 3:  
    class_index = 1  # Change if needed
    shap_values = shap_values[:, :, class_index]

# Ensure shape matches
shap_values = np.array(shap_values)

# Plot summary (bar chart)
shap.summary_plot(shap_values, x_test, plot_type="bar")
# Out:
# SHAP Values Shape: (230, 20, 2)
# x_test Shape: (230, 20)

# %%
import shap

# Ensure expected_value is a scalar
base_value = explainer.expected_value[1]
if hasattr(base_value, 'numpy'):
    base_value = base_value.numpy()  # Convert to NumPy if it's a tensor

# Waterfall Plot for the first sample (Class 1)
shap.waterfall_plot(shap.Explanation(
    values=shap_values[0, :, 1],
    base_values=base_value,
    data=x_test.iloc[0],
    feature_names=feature_names
))
